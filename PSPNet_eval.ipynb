# %%
cd /content/drive/My Drive/Colab Notebooks/Eval_brain_mri
# Out:
# /content/drive/My Drive/Colab Notebooks/Eval_brain_mri

# %%
import os
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2

import torch

# %%
def show_image(img):
  plt.imshow(img)
  plt.show()

# %%
from utils.dataloader import make_datapath_list, DataTransform, BrainDataset
rootpath = os.path.abspath("")
makepath = make_datapath_list(rootpath)
test_img_list, test_anno_list = makepath.get_list("test")

# %%
from utils.pspnet import PSPNet

net = PSPNet(n_classes = 2)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
state_dict = torch.load('weights/pspnet50_15.pth', map_location={"cuda:0": "cpu"})
net.load_state_dict(state_dict)
net.to(device)
# Out:
# PSPNet(
#   (feature_conv): FeatureMap_convolution(
#     (cbnr_1): conv2DBatchNormRelu(
#       (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (cbnr_2): conv2DBatchNormRelu(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (cbnr_3): conv2DBatchNormRelu(
#       (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (feature_res_1): ResidualBlockPSP(
#     (block1): bottleNeckPSP(
#       (cbr_1): conv2DBatchNormRelu(
#         (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cbr_2): conv2DBatchNormRelu(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cb_3): conv2DBatchNorm(
#         (conv): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (cb_residual): conv2DBatchNorm(
#         (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (block2): bottleNeckIdentifyPSP(
#       (cbr_1): conv2DBatchNormRelu(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cbr_2): conv2DBatchNormRelu(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cb_3): conv2DBatchNorm(
#         (conv): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (block3): bottleNeckIdentifyPSP(
#       (cbr_1): conv2DBatchNormRelu(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cbr_2): conv2DBatchNormRelu(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cb_3): conv2DBatchNorm(
#         (conv): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (feature_res_2): ResidualBlockPSP(
#     (block1): bottleNeckPSP(
#       (cbr_1): conv2DBatchNormRelu(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cbr_2): conv2DBatchNormRelu(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cb_3): conv2DBatchNorm(
#         (conv): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (cb_residual): conv2DBatchNorm(
#         (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (block2): bottleNeckIdentifyPSP(
#       (cbr_1): conv2DBatchNormRelu(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cbr_2): conv2DBatchNormRelu(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cb_3): conv2DBatchNorm(
#         (conv): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (block3): bottleNeckIdentifyPSP(
#       (cbr_1): conv2DBatchNormRelu(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cbr_2): conv2DBatchNormRelu(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cb_3): conv2DBatchNorm(
#         (conv): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (block4): bottleNeckIdentifyPSP(
#       (cbr_1): conv2DBatchNormRelu(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cbr_2): conv2DBatchNormRelu(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cb_3): conv2DBatchNorm(
#         (conv): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (feature_dilated_res_1): ResidualBlockPSP(
#     (block1): bottleNeckPSP(
#       (cbr_1): conv2DBatchNormRelu(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cbr_2): conv2DBatchNormRelu(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cb_3): conv2DBatchNorm(
#         (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (cb_residual): conv2DBatchNorm(
#         (conv): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (block2): bottleNeckIdentifyPSP(
#       (cbr_1): conv2DBatchNormRelu(
#         (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cbr_2): conv2DBatchNormRelu(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cb_3): conv2DBatchNorm(
#         (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (block3): bottleNeckIdentifyPSP(
#       (cbr_1): conv2DBatchNormRelu(
#         (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cbr_2): conv2DBatchNormRelu(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cb_3): conv2DBatchNorm(
#         (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (block4): bottleNeckIdentifyPSP(
#       (cbr_1): conv2DBatchNormRelu(
#         (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cbr_2): conv2DBatchNormRelu(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cb_3): conv2DBatchNorm(
#         (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (block5): bottleNeckIdentifyPSP(
#       (cbr_1): conv2DBatchNormRelu(
#         (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cbr_2): conv2DBatchNormRelu(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cb_3): conv2DBatchNorm(
#         (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (block6): bottleNeckIdentifyPSP(
#       (cbr_1): conv2DBatchNormRelu(
#         (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cbr_2): conv2DBatchNormRelu(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cb_3): conv2DBatchNorm(
#         (conv): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (feature_dilated_res_2): ResidualBlockPSP(
#     (block1): bottleNeckPSP(
#       (cbr_1): conv2DBatchNormRelu(
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cbr_2): conv2DBatchNormRelu(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cb_3): conv2DBatchNorm(
#         (conv): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (cb_residual): conv2DBatchNorm(
#         (conv): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (block2): bottleNeckIdentifyPSP(
#       (cbr_1): conv2DBatchNormRelu(
#         (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cbr_2): conv2DBatchNormRelu(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cb_3): conv2DBatchNorm(
#         (conv): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (block3): bottleNeckIdentifyPSP(
#       (cbr_1): conv2DBatchNormRelu(
#         (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cbr_2): conv2DBatchNormRelu(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (cb_3): conv2DBatchNorm(
#         (conv): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (batchnorm): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (pyramid_pooling): PyramidPooling(
#     (avpool_1): AdaptiveAvgPool2d(output_size=6)
#     (cbr_1): conv2DBatchNormRelu(
#       (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (avpool_2): AdaptiveAvgPool2d(output_size=3)
#     (cbr_2): conv2DBatchNormRelu(
#       (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (avpool_3): AdaptiveAvgPool2d(output_size=2)
#     (cbr_3): conv2DBatchNormRelu(
#       (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (avpool_4): AdaptiveAvgPool2d(output_size=1)
#     (cbr_4): conv2DBatchNormRelu(
#       (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (decode_feature): DecodePSPFeature(
#     (cbr): conv2DBatchNormRelu(
#       (conv): Conv2d(4096, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (classification): Conv2d(512, 2, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (aux): AuxiliaryPSPlayers(
#     (cbr): conv2DBatchNormRelu(
#       (conv): Conv2d(1024, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (classification): Conv2d(256, 2, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
class PSPNet_make_mask():
  """
  function: This function can make the inference mask of PSPnet model.
  """

  def __init__(self, img_path_list, anno_path_list, net, input_size, device):
    """
    input
    -------------------------------------
    img_path_list: List of image paths to infer
    anno_path_list: List of anno paths
    net: Pretrained PSPNet model
    input_size: The size of the image to enter into the model
    """
    self.img_path_list = img_path_list
    self.anno_path_list = anno_path_list
    self.net = net.to(device)
    self.device = device
    self.transform = DataTransform(input_size=input_size)
  
  def make_mask(self, idx):
    """
    input
    -------------------------------------
    idx: Index number of the path
    -------------------------------------

    output
    -------------------------------------
    inference_mask: Inference result mask
    annotaion_mask: Grand truth mask
    -------------------------------------
    """
    image_file_path = self.img_path_list[idx]
    anno_file_path = self.anno_path_list[idx]

    img = Image.open(image_file_path)
    img_width, img_height = img.size

    anno_class_img = Image.open(anno_file_path) 
    anno_class_img = anno_class_img.convert('P')
    annotation_mask = anno_class_img

    img, anno_class_img = self.transform("val", img, anno_class_img)

    self.net.eval()
    x = img.unsqueeze(0)
    x = x.to(self.device, dtype=torch.float)
    outputs = self.net(x)
    y = outputs[0]
    device2 = torch.device('cpu')
    y = y.to(device2)
    y = y[0].detach().numpy()
    y = np.argmax(y, axis=0)

    annotation_mask = np.array(annotation_mask)
    annotation_mask = np.where(annotation_mask==0, 0, 1)
    inference_mask = cv2.resize(np.uint8(y), (img_width, img_height))
    inference_mask = np.where(inference_mask==0, 0, 1)

    return inference_mask, annotation_mask

  def IoU(self, idx, return_mask=False):

    pred_mask, truth_mask = self.make_mask(idx)    
    tp = np.count_nonzero((truth_mask ==1) & (pred_mask == 1))
    tn = np.count_nonzero((truth_mask ==0) & (pred_mask == 0))
    fn = np.count_nonzero((truth_mask ==1) & (pred_mask == 0))
    fp = np.count_nonzero((truth_mask ==0) & (pred_mask == 1))

    if (tp + fp + fn) == 0:
      iou = 100
      detect = 'All_TN'
    elif tp == 0 and fp == 0:
      iou = tp/(tp + fp + fn)*100
      detect = 'No_detect'
    elif tp == 0 and fn == 0:
      iou = tp/(tp + fp + fn)*100
      detect = 'Mis_detect'
    else:
      iou = tp/(tp + fp + fn)*100
      detect = 'Detect'

    if return_mask:
      return pred_mask, truth_mask, iou, detect
    else:
      return iou, detect

# %%
pspnet_mask = PSPNet_make_mask(test_img_list, test_anno_list, net, 475, device)
inference_mask, annotation_mask = pspnet_mask.make_mask(20)
show_image(inference_mask)
show_image(annotation_mask)

# %%
#from utils.pspnet_iou import PSPNet_make_mask
pspnet_mask = PSPNet_make_mask(test_img_list, test_anno_list, net, 475, device)
inference_mask, annotation_mask, iou, detect = pspnet_mask.IoU(20, return_mask=True)
print(iou, detect)
show_image(inference_mask)
show_image(annotation_mask)
# Out:
# 32.62331838565022 Detect

# %%
pspnet_mask = PSPNet_make_mask(test_img_list, test_anno_list, net, 475, device)
index = [] 
result_iou = []
columns = ["iou", 'detect']
count_no_detect = 0
count_mis_detect = 0
sum_iou = 0
count = 0
for i, img_path in enumerate(test_img_list):
  add_path = img_path.split('/')[-1]
  iou, detect = pspnet_mask.IoU(i)
  if detect == "Detect":
    sum_iou += iou
    count += 1
  elif detect == "No_detect":
    count_no_detect += 1
  elif detect == "Mis_detect":
    count_mis_detect += 1

  iou = str(iou)
  index.append(add_path)
  result_iou.append([iou, detect])

  print('Number:', i, 'IoU:', iou, "detect:", detect)
print('Average IoU:', sum_iou/count)
index.append("avg iou")
result_iou.append([str(sum_iou/count), ''])
# Out:
# Number: 0 IoU: 100 detect: All_TN
# Number: 1 IoU: 100 detect: All_TN
# Number: 2 IoU: 100 detect: All_TN
# Number: 3 IoU: 100 detect: All_TN
# Number: 4 IoU: 100 detect: All_TN
# Number: 5 IoU: 100 detect: All_TN
# Number: 6 IoU: 100 detect: All_TN
# Number: 7 IoU: 100 detect: All_TN
# Number: 8 IoU: 100 detect: All_TN
# Number: 9 IoU: 100 detect: All_TN
# Number: 10 IoU: 100 detect: All_TN
# Number: 11 IoU: 100 detect: All_TN
# Number: 12 IoU: 100 detect: All_TN
# Number: 13 IoU: 100 detect: All_TN
# Number: 14 IoU: 100 detect: All_TN
# Number: 15 IoU: 0.0 detect: No_detect
# Number: 16 IoU: 0.0 detect: No_detect
# Number: 17 IoU: 0.0 detect: No_detect
# Number: 18 IoU: 0.0 detect: No_detect
# Number: 19 IoU: 1.762632197414806 detect: Detect
# Number: 20 IoU: 32.62331838565022 detect: Detect
# Number: 21 IoU: 40.73006724303554 detect: Detect
# Number: 22 IoU: 100 detect: All_TN
# Number: 23 IoU: 0.0 detect: No_detect
# Number: 24 IoU: 41.60206718346253 detect: Detect
# Number: 25 IoU: 17.24470134874759 detect: Detect
# Number: 26 IoU: 0.0 detect: No_detect
# Number: 27 IoU: 0.0 detect: No_detect
# Number: 28 IoU: 0.0 detect: No_detect
# Number: 29 IoU: 0.0 detect: No_detect
# Number: 30 IoU: 0.0 detect: No_detect
# Number: 31 IoU: 0.0 detect: No_detect
# Number: 32 IoU: 0.0 detect: No_detect
# Number: 33 IoU: 100 detect: All_TN
# Number: 34 IoU: 100 detect: All_TN
# Number: 35 IoU: 100 detect: All_TN
# Number: 36 IoU: 100 detect: All_TN
# Number: 37 IoU: 100 detect: All_TN
# Number: 38 IoU: 100 detect: All_TN
# Number: 39 IoU: 100 detect: All_TN
# Number: 40 IoU: 100 detect: All_TN
# Number: 41 IoU: 100 detect: All_TN
# Number: 42 IoU: 100 detect: All_TN
# Number: 43 IoU: 100 detect: All_TN
# Number: 44 IoU: 100 detect: All_TN
# Number: 45 IoU: 100 detect: All_TN
# Number: 46 IoU: 100 detect: All_TN
# Number: 47 IoU: 100 detect: All_TN
# Number: 48 IoU: 100 detect: All_TN
# Number: 49 IoU: 100 detect: All_TN
# Number: 50 IoU: 100 detect: All_TN
# Number: 51 IoU: 100 detect: All_TN
# Number: 52 IoU: 100 detect: All_TN
# Number: 53 IoU: 100 detect: All_TN
# Number: 54 IoU: 100 detect: All_TN
# Number: 55 IoU: 100 detect: All_TN
# Number: 56 IoU: 100 detect: All_TN
# Number: 57 IoU: 100 detect: All_TN
# Number: 58 IoU: 100 detect: All_TN
# Number: 59 IoU: 100 detect: All_TN
# Number: 60 IoU: 100 detect: All_TN
# Number: 61 IoU: 100 detect: All_TN
# Number: 62 IoU: 100 detect: All_TN
# Number: 63 IoU: 100 detect: All_TN
# Number: 64 IoU: 100 detect: All_TN
# Number: 65 IoU: 100 detect: All_TN
# Number: 66 IoU: 100 detect: All_TN
# Number: 67 IoU: 100 detect: All_TN
# Number: 68 IoU: 100 detect: All_TN
# Number: 69 IoU: 100 detect: All_TN
# Number: 70 IoU: 100 detect: All_TN
# Number: 71 IoU: 100 detect: All_TN
# Number: 72 IoU: 100 detect: All_TN
# Number: 73 IoU: 100 detect: All_TN
# Number: 74 IoU: 100 detect: All_TN
# Number: 75 IoU: 100 detect: All_TN
# Number: 76 IoU: 100 detect: All_TN
# Number: 77 IoU: 100 detect: All_TN
# Number: 78 IoU: 100 detect: All_TN
# Number: 79 IoU: 100 detect: All_TN
# Number: 80 IoU: 100 detect: All_TN
# Number: 81 IoU: 100 detect: All_TN
# Number: 82 IoU: 0.0 detect: No_detect
# Number: 83 IoU: 6.384248210023865 detect: Detect
# Number: 84 IoU: 22.89899768696993 detect: Detect
# Number: 85 IoU: 19.729907773386035 detect: Detect
# Number: 86 IoU: 77.25060827250608 detect: Detect
# Number: 87 IoU: 75.90679270169268 detect: Detect
# Number: 88 IoU: 49.98961146893829 detect: Detect
# Number: 89 IoU: 53.05931807566557 detect: Detect
# Number: 90 IoU: 66.09107188539268 detect: Detect
# Number: 91 IoU: 100 detect: All_TN
# Number: 92 IoU: 66.02939078327864 detect: Detect
# Number: 93 IoU: 65.43579010315443 detect: Detect
# Number: 94 IoU: 22.64565775009161 detect: Detect
# Number: 95 IoU: 43.09116809116809 detect: Detect
# Number: 96 IoU: 60.48336472065286 detect: Detect
# Number: 97 IoU: 63.528896672504374 detect: Detect
# Number: 98 IoU: 45.09803921568628 detect: Detect
# Number: 99 IoU: 1.3278008298755186 detect: Detect
# Number: 100 IoU: 100 detect: All_TN
# Number: 101 IoU: 100 detect: All_TN
# Number: 102 IoU: 100 detect: All_TN
# Number: 103 IoU: 100 detect: All_TN
# Number: 104 IoU: 100 detect: All_TN
# Number: 105 IoU: 100 detect: All_TN
# Number: 106 IoU: 100 detect: All_TN
# Number: 107 IoU: 100 detect: All_TN
# Number: 108 IoU: 100 detect: All_TN
# Number: 109 IoU: 100 detect: All_TN
# Number: 110 IoU: 100 detect: All_TN
# Number: 111 IoU: 100 detect: All_TN
# Number: 112 IoU: 100 detect: All_TN
# Number: 113 IoU: 83.27598072952512 detect: Detect
# Number: 114 IoU: 85.53459119496856 detect: Detect
# Number: 115 IoU: 0.0 detect: No_detect
# Number: 116 IoU: 100 detect: All_TN
# Number: 117 IoU: 100 detect: All_TN
# Number: 118 IoU: 100 detect: All_TN
# Number: 119 IoU: 100 detect: All_TN
# Number: 120 IoU: 100 detect: All_TN
# Number: 121 IoU: 100 detect: All_TN
# Number: 122 IoU: 100 detect: All_TN
# Number: 123 IoU: 100 detect: All_TN
# Number: 124 IoU: 100 detect: All_TN
# Number: 125 IoU: 100 detect: All_TN
# Number: 126 IoU: 100 detect: All_TN
# Number: 127 IoU: 100 detect: All_TN
# Number: 128 IoU: 70.84805653710248 detect: Detect
# Number: 129 IoU: 84.06445837063563 detect: Detect
# Number: 130 IoU: 84.92753623188406 detect: Detect
# Number: 131 IoU: 85.83333333333333 detect: Detect
# Number: 132 IoU: 100 detect: All_TN
# Number: 133 IoU: 75.09859154929578 detect: Detect
# Number: 134 IoU: 0.0 detect: No_detect
# Number: 135 IoU: 100 detect: All_TN
# Number: 136 IoU: 100 detect: All_TN
# Number: 137 IoU: 100 detect: All_TN
# Number: 138 IoU: 100 detect: All_TN
# Number: 139 IoU: 100 detect: All_TN
# Number: 140 IoU: 100 detect: All_TN
# Number: 141 IoU: 100 detect: All_TN
# Number: 142 IoU: 100 detect: All_TN
# Number: 143 IoU: 100 detect: All_TN
# Number: 144 IoU: 100 detect: All_TN
# Number: 145 IoU: 100 detect: All_TN
# Number: 146 IoU: 100 detect: All_TN
# Number: 147 IoU: 100 detect: All_TN
# Number: 148 IoU: 100 detect: All_TN
# Number: 149 IoU: 31.070287539936103 detect: Detect
# Number: 150 IoU: 82.79620853080569 detect: Detect
# Number: 151 IoU: 73.27847553053269 detect: Detect
# Number: 152 IoU: 100 detect: All_TN
# Number: 153 IoU: 100 detect: All_TN
# Number: 154 IoU: 100 detect: All_TN
# Number: 155 IoU: 100 detect: All_TN
# Number: 156 IoU: 100 detect: All_TN
# Number: 157 IoU: 0.0 detect: No_detect
# Number: 158 IoU: 0.0 detect: No_detect
# Number: 159 IoU: 0.0 detect: No_detect
# Number: 160 IoU: 0.0 detect: No_detect
# Number: 161 IoU: 0.0 detect: No_detect
# Number: 162 IoU: 0.0 detect: No_detect
# Number: 163 IoU: 100 detect: All_TN
# Number: 164 IoU: 1.7697678194512094 detect: Detect
# Number: 165 IoU: 3.7154508382419573 detect: Detect
# Number: 166 IoU: 5.148182095936449 detect: Detect
# Number: 167 IoU: 3.7846655791190864 detect: Detect
# Number: 168 IoU: 4.886943836615609 detect: Detect
# Number: 169 IoU: 0.0 detect: No_detect
# Number: 170 IoU: 3.7109924093337083 detect: Detect
# Number: 171 IoU: 0.0 detect: No_detect
# Number: 172 IoU: 0.0 detect: No_detect
# Number: 173 IoU: 0.0 detect: No_detect
# Number: 174 IoU: 100 detect: All_TN
# Number: 175 IoU: 0.0 detect: No_detect
# Number: 176 IoU: 100 detect: All_TN
# Number: 177 IoU: 100 detect: All_TN
# Number: 178 IoU: 100 detect: All_TN
# Number: 179 IoU: 100 detect: All_TN
# Number: 180 IoU: 100 detect: All_TN
# Number: 181 IoU: 100 detect: All_TN
# Number: 182 IoU: 100 detect: All_TN
# Number: 183 IoU: 100 detect: All_TN
# Number: 184 IoU: 100 detect: All_TN
# Number: 185 IoU: 75.359477124183 detect: Detect
# Number: 186 IoU: 77.77383906416165 detect: Detect
# Number: 187 IoU: 58.58461538461538 detect: Detect
# Number: 188 IoU: 75.94339622641509 detect: Detect
# Number: 189 IoU: 66.53992395437263 detect: Detect
# Number: 190 IoU: 68.65605658709107 detect: Detect
# Number: 191 IoU: 68.97382920110194 detect: Detect
# Number: 192 IoU: 67.98655211057152 detect: Detect
# Number: 193 IoU: 40.264976958525345 detect: Detect
# Number: 194 IoU: 0.0 detect: No_detect
# Number: 195 IoU: 100 detect: All_TN
# Number: 196 IoU: 0.0 detect: No_detect
# Number: 197 IoU: 100 detect: All_TN
# Number: 198 IoU: 100 detect: All_TN
# Number: 199 IoU: 100 detect: All_TN
# Number: 200 IoU: 100 detect: All_TN
# Number: 201 IoU: 100 detect: All_TN
# Number: 202 IoU: 100 detect: All_TN
# Number: 203 IoU: 100 detect: All_TN
# Number: 204 IoU: 70.65989847715736 detect: Detect
# Number: 205 IoU: 75.74437182280319 detect: Detect
# Number: 206 IoU: 100 detect: All_TN
# Number: 207 IoU: 50.15733165512901 detect: Detect
# Number: 208 IoU: 33.460559796437664 detect: Detect
# Number: 209 IoU: 60.03627569528416 detect: Detect
# Number: 210 IoU: 33.46855983772819 detect: Detect
# Number: 211 IoU: 12.313937753721245 detect: Detect
# Number: 212 IoU: 100 detect: All_TN
# Number: 213 IoU: 100 detect: All_TN
# Number: 214 IoU: 100 detect: All_TN
# Number: 215 IoU: 100 detect: All_TN
# Number: 216 IoU: 100 detect: All_TN
# Number: 217 IoU: 100 detect: All_TN
# Number: 218 IoU: 100 detect: All_TN
# Number: 219 IoU: 100 detect: All_TN
# Number: 220 IoU: 100 detect: All_TN
# Number: 221 IoU: 100 detect: All_TN
# Number: 222 IoU: 100 detect: All_TN
# Number: 223 IoU: 100 detect: All_TN
# Number: 224 IoU: 50.84269662921348 detect: Detect
# Number: 225 IoU: 34.87179487179487 detect: Detect
# Number: 226 IoU: 100 detect: All_TN
# Number: 227 IoU: 100 detect: All_TN
# Number: 228 IoU: 100 detect: All_TN
# Number: 229 IoU: 100 detect: All_TN
# Number: 230 IoU: 100 detect: All_TN
# Number: 231 IoU: 85.43689320388349 detect: Detect
# Number: 232 IoU: 83.44914718888187 detect: Detect
# Number: 233 IoU: 81.25613346418056 detect: Detect
# Number: 234 IoU: 82.18765679879579 detect: Detect
# Number: 235 IoU: 77.42525930445393 detect: Detect
# Number: 236 IoU: 77.35085945399393 detect: Detect
# Number: 237 IoU: 100 detect: All_TN
# Number: 238 IoU: 0.7653061224489796 detect: Detect
# Number: 239 IoU: 100 detect: All_TN
# Number: 240 IoU: 100 detect: All_TN
# Number: 241 IoU: 100 detect: All_TN
# Number: 242 IoU: 100 detect: All_TN
# Number: 243 IoU: 100 detect: All_TN
# Number: 244 IoU: 100 detect: All_TN
# Number: 245 IoU: 100 detect: All_TN
# Number: 246 IoU: 100 detect: All_TN
# Number: 247 IoU: 100 detect: All_TN
# Number: 248 IoU: 100 detect: All_TN
# Number: 249 IoU: 100 detect: All_TN
# Number: 250 IoU: 100 detect: All_TN
# Number: 251 IoU: 0.0 detect: No_detect
# Number: 252 IoU: 46.72645739910314 detect: Detect
# Number: 253 IoU: 52.068345323741006 detect: Detect
# Number: 254 IoU: 74.9290060851927 detect: Detect
# Number: 255 IoU: 66.27944498225234 detect: Detect
# Number: 256 IoU: 70.990990990991 detect: Detect
# Number: 257 IoU: 74.40203562340967 detect: Detect
# Number: 258 IoU: 56.32582322357019 detect: Detect
# Number: 259 IoU: 100 detect: All_TN
# Number: 260 IoU: 65.95744680851064 detect: Detect
# Number: 261 IoU: 100 detect: All_TN
# Number: 262 IoU: 100 detect: All_TN
# Number: 263 IoU: 100 detect: All_TN
# Number: 264 IoU: 100 detect: All_TN
# Number: 265 IoU: 100 detect: All_TN
# Number: 266 IoU: 100 detect: All_TN
# Number: 267 IoU: 100 detect: All_TN
# Number: 268 IoU: 100 detect: All_TN
# Number: 269 IoU: 100 detect: All_TN
# Number: 270 IoU: 0.0 detect: No_detect
# Number: 271 IoU: 64.8846960167715 detect: Detect
# Number: 272 IoU: 74.04770380918477 detect: Detect
# Number: 273 IoU: 81.12218143681174 detect: Detect
# Number: 274 IoU: 91.21747211895911 detect: Detect
# Number: 275 IoU: 89.5483565854812 detect: Detect
# Number: 276 IoU: 88.02973977695167 detect: Detect
# Number: 277 IoU: 89.2875851231011 detect: Detect
# Number: 278 IoU: 85.33083645443196 detect: Detect
# Number: 279 IoU: 86.20850864890136 detect: Detect
# Number: 280 IoU: 100 detect: All_TN
# Number: 281 IoU: 27.352572145545796 detect: Detect
# Number: 282 IoU: 100 detect: All_TN
# Number: 283 IoU: 100 detect: All_TN
# Number: 284 IoU: 100 detect: All_TN
# Number: 285 IoU: 100 detect: All_TN
# Number: 286 IoU: 100 detect: All_TN
# Number: 287 IoU: 100 detect: All_TN
# Number: 288 IoU: 100 detect: All_TN
# Number: 289 IoU: 100 detect: All_TN
# Number: 290 IoU: 100 detect: All_TN
# Number: 291 IoU: 100 detect: All_TN
# Number: 292 IoU: 67.61229314420804 detect: Detect
# Number: 293 IoU: 91.48466257668711 detect: Detect
# Number: 294 IoU: 81.45016653856008 detect: Detect
# Number: 295 IoU: 81.53603366649132 detect: Detect
# Number: 296 IoU: 57.91201575837164 detect: Detect
# Number: 297 IoU: 81.77429088714544 detect: Detect
# Number: 298 IoU: 30.161290322580648 detect: Detect
# Number: 299 IoU: 100 detect: All_TN
# Number: 300 IoU: 100 detect: All_TN
# Number: 301 IoU: 100 detect: All_TN
# Number: 302 IoU: 100 detect: All_TN
# Number: 303 IoU: 100 detect: All_TN
# Number: 304 IoU: 100 detect: All_TN
# Number: 305 IoU: 100 detect: All_TN
# Number: 306 IoU: 100 detect: All_TN
# Number: 307 IoU: 100 detect: All_TN
# Number: 308 IoU: 100 detect: All_TN
# Number: 309 IoU: 100 detect: All_TN
# Number: 310 IoU: 100 detect: All_TN
# Number: 311 IoU: 100 detect: All_TN
# Number: 312 IoU: 40.604026845637584 detect: Detect
# Number: 313 IoU: 79.7550432276657 detect: Detect
# Number: 314 IoU: 100 detect: All_TN
# Number: 315 IoU: 100 detect: All_TN
# Number: 316 IoU: 100 detect: All_TN
# Number: 317 IoU: 100 detect: All_TN
# Number: 318 IoU: 100 detect: All_TN
# Number: 319 IoU: 100 detect: All_TN
# Number: 320 IoU: 0.0 detect: No_detect
# Number: 321 IoU: 5.36480686695279 detect: Detect
# Number: 322 IoU: 45.1213925790197 detect: Detect
# Number: 323 IoU: 22.383252818035427 detect: Detect
# Number: 324 IoU: 7.007575757575757 detect: Detect
# Number: 325 IoU: 100 detect: All_TN
# Number: 326 IoU: 0.0 detect: No_detect
# Number: 327 IoU: 0.0 detect: No_detect
# Number: 328 IoU: 0.0 detect: No_detect
# Number: 329 IoU: 0.0 detect: No_detect
# Number: 330 IoU: 0.0 detect: No_detect
# Number: 331 IoU: 0.0 detect: No_detect
# Number: 332 IoU: 0.0 detect: No_detect
# Number: 333 IoU: 0.0 detect: No_detect
# Number: 334 IoU: 0.0 detect: No_detect
# Number: 335 IoU: 0.0 detect: No_detect
# Number: 336 IoU: 100 detect: All_TN
# Number: 337 IoU: 100 detect: All_TN
# Number: 338 IoU: 100 detect: All_TN
# Number: 339 IoU: 100 detect: All_TN
# Number: 340 IoU: 100 detect: All_TN
# Number: 341 IoU: 100 detect: All_TN
# Number: 342 IoU: 100 detect: All_TN
# Number: 343 IoU: 100 detect: All_TN
# Number: 344 IoU: 100 detect: All_TN
# Number: 345 IoU: 100 detect: All_TN
# Number: 346 IoU: 100 detect: All_TN
# Number: 347 IoU: 100 detect: All_TN
# Number: 348 IoU: 100 detect: All_TN
# Number: 349 IoU: 0.0 detect: No_detect
# Number: 350 IoU: 0.0 detect: No_detect
# Number: 351 IoU: 0.0 detect: No_detect
# Number: 352 IoU: 0.0 detect: No_detect
# Number: 353 IoU: 0.0 detect: No_detect
# Number: 354 IoU: 0.0 detect: No_detect
# Number: 355 IoU: 31.072749691738593 detect: Detect
# Number: 356 IoU: 0.0 detect: No_detect
# Number: 357 IoU: 100 detect: All_TN
# Number: 358 IoU: 0.0 detect: No_detect
# Number: 359 IoU: 0.0 detect: No_detect
# Number: 360 IoU: 0.0 detect: No_detect
# Number: 361 IoU: 100 detect: All_TN
# Number: 362 IoU: 100 detect: All_TN
# Number: 363 IoU: 100 detect: All_TN
# Number: 364 IoU: 100 detect: All_TN
# Number: 365 IoU: 100 detect: All_TN
# Number: 366 IoU: 100 detect: All_TN
# Number: 367 IoU: 100 detect: All_TN
# Number: 368 IoU: 100 detect: All_TN
# Number: 369 IoU: 100 detect: All_TN
# Number: 370 IoU: 100 detect: All_TN
# Number: 371 IoU: 100 detect: All_TN
# Number: 372 IoU: 100 detect: All_TN
# Number: 373 IoU: 100 detect: All_TN
# Number: 374 IoU: 100 detect: All_TN
# Number: 375 IoU: 100 detect: All_TN
# Number: 376 IoU: 100 detect: All_TN
# Number: 377 IoU: 100 detect: All_TN
# Number: 378 IoU: 100 detect: All_TN
# Number: 379 IoU: 100 detect: All_TN
# Number: 380 IoU: 100 detect: All_TN
# Number: 381 IoU: 100 detect: All_TN
# Number: 382 IoU: 100 detect: All_TN
# Number: 383 IoU: 100 detect: All_TN
# Number: 384 IoU: 100 detect: All_TN
# Number: 385 IoU: 100 detect: All_TN
# Number: 386 IoU: 100 detect: All_TN
# Number: 387 IoU: 100 detect: All_TN
# Number: 388 IoU: 0.0 detect: No_detect
# Number: 389 IoU: 0.0 detect: No_detect
# Number: 390 IoU: 0.0 detect: No_detect
# Number: 391 IoU: 0.0 detect: No_detect
# Number: 392 IoU: 0.0 detect: No_detect
# Number: 393 IoU: 0.0 detect: No_detect
# Number: 394 IoU: 0.0 detect: No_detect
# Number: 395 IoU: 0.0 detect: No_detect
# Number: 396 IoU: 100 detect: All_TN
# Number: 397 IoU: 0.0 detect: No_detect
# Number: 398 IoU: 0.0 detect: No_detect
# Number: 399 IoU: 0.0 detect: No_detect
# Number: 400 IoU: 0.0 detect: No_detect
# Number: 401 IoU: 7.843977711101586 detect: Detect
# Number: 402 IoU: 20.357275772236697 detect: Detect
# Number: 403 IoU: 2.5305778152678196 detect: Detect
# Number: 404 IoU: 7.1764705882352935 detect: Detect
# Number: 405 IoU: 0.8909630886720408 detect: Detect
# Number: 406 IoU: 56.99645250295625 detect: Detect
# Number: 407 IoU: 100 detect: All_TN
# Number: 408 IoU: 0.22593764121102575 detect: Detect
# Number: 409 IoU: 29.33487120338331 detect: Detect
# Number: 410 IoU: 17.294451194815714 detect: Detect
# Number: 411 IoU: 50.8765243902439 detect: Detect
# Number: 412 IoU: 1.222992254382389 detect: Detect
# Number: 413 IoU: 13.6700812433769 detect: Detect
# Number: 414 IoU: 13.546910755148742 detect: Detect
# Number: 415 IoU: 30.470770822555615 detect: Detect
# Number: 416 IoU: 28.868017795353435 detect: Detect
# Number: 417 IoU: 50.513347022587276 detect: Detect
# Number: 418 IoU: 100 detect: All_TN
# Number: 419 IoU: 0.3875968992248062 detect: Detect
# Number: 420 IoU: 64.50809464508094 detect: Detect
# Number: 421 IoU: 42.310418143160874 detect: Detect
# Number: 422 IoU: 66.43307638402243 detect: Detect
# Number: 423 IoU: 73.30508474576271 detect: Detect
# Number: 424 IoU: 0.0 detect: No_detect
# Number: 425 IoU: 0.0 detect: No_detect
# Number: 426 IoU: 0.0 detect: No_detect
# Number: 427 IoU: 0.0 detect: Detect
# Number: 428 IoU: 100 detect: All_TN
# Number: 429 IoU: 100 detect: All_TN
# Number: 430 IoU: 100 detect: All_TN
# Number: 431 IoU: 100 detect: All_TN
# Number: 432 IoU: 100 detect: All_TN
# Number: 433 IoU: 100 detect: All_TN
# Number: 434 IoU: 100 detect: All_TN
# Number: 435 IoU: 100 detect: All_TN
# Number: 436 IoU: 100 detect: All_TN
# Number: 437 IoU: 100 detect: All_TN
# Number: 438 IoU: 100 detect: All_TN
# Number: 439 IoU: 100 detect: All_TN
# Number: 440 IoU: 100 detect: All_TN
# Number: 441 IoU: 100 detect: All_TN
# Number: 442 IoU: 100 detect: All_TN
# Number: 443 IoU: 100 detect: All_TN
# Number: 444 IoU: 100 detect: All_TN
# Number: 445 IoU: 100 detect: All_TN
# Number: 446 IoU: 100 detect: All_TN
# Number: 447 IoU: 100 detect: All_TN
# Number: 448 IoU: 100 detect: All_TN
# Number: 449 IoU: 100 detect: All_TN
# Number: 450 IoU: 100 detect: All_TN
# Number: 451 IoU: 100 detect: All_TN
# Number: 452 IoU: 100 detect: All_TN
# Number: 453 IoU: 100 detect: All_TN
# Number: 454 IoU: 100 detect: All_TN
# Number: 455 IoU: 100 detect: All_TN
# Number: 456 IoU: 100 detect: All_TN
# Number: 457 IoU: 100 detect: All_TN
# Number: 458 IoU: 100 detect: All_TN
# Number: 459 IoU: 100 detect: All_TN
# Number: 460 IoU: 100 detect: All_TN
# Number: 461 IoU: 100 detect: All_TN
# Number: 462 IoU: 100 detect: All_TN
# Number: 463 IoU: 100 detect: All_TN
# Number: 464 IoU: 100 detect: All_TN
# Number: 465 IoU: 100 detect: All_TN
# Number: 466 IoU: 100 detect: All_TN
# Number: 467 IoU: 100 detect: All_TN
# Number: 468 IoU: 100 detect: All_TN
# Number: 469 IoU: 100 detect: All_TN
# Number: 470 IoU: 100 detect: All_TN
# Number: 471 IoU: 100 detect: All_TN
# Number: 472 IoU: 100 detect: All_TN
# Number: 473 IoU: 100 detect: All_TN
# Number: 474 IoU: 100 detect: All_TN
# Number: 475 IoU: 100 detect: All_TN
# Number: 476 IoU: 100 detect: All_TN
# Number: 477 IoU: 100 detect: All_TN
# Number: 478 IoU: 100 detect: All_TN
# Number: 479 IoU: 0.0 detect: No_detect
# Number: 480 IoU: 0.0 detect: No_detect
# Number: 481 IoU: 0.0 detect: No_detect
# Number: 482 IoU: 0.0 detect: No_detect
# Number: 483 IoU: 0.0 detect: No_detect
# Number: 484 IoU: 100 detect: All_TN
# Number: 485 IoU: 0.0 detect: No_detect
# Number: 486 IoU: 0.0 detect: No_detect
# Number: 487 IoU: 0.0 detect: No_detect
# Number: 488 IoU: 0.0 detect: No_detect
# Number: 489 IoU: 0.0 detect: No_detect
# Number: 490 IoU: 0.0 detect: No_detect
# Number: 491 IoU: 0.0 detect: No_detect
# Number: 492 IoU: 0.0 detect: No_detect
# Number: 493 IoU: 0.0 detect: No_detect
# Number: 494 IoU: 0.0 detect: No_detect
# Number: 495 IoU: 100 detect: All_TN
# Number: 496 IoU: 0.0 detect: No_detect
# Number: 497 IoU: 0.0 detect: No_detect
# Number: 498 IoU: 0.0 detect: No_detect
# Number: 499 IoU: 0.0 detect: No_detect
# Number: 500 IoU: 0.0 detect: No_detect
# Number: 501 IoU: 0.0 detect: No_detect
# Number: 502 IoU: 0.0 detect: No_detect
# Number: 503 IoU: 0.0 detect: No_detect
# Number: 504 IoU: 0.0 detect: No_detect
# Number: 505 IoU: 0.0 detect: No_detect
# Number: 506 IoU: 100 detect: All_TN
# Number: 507 IoU: 100 detect: All_TN
# Number: 508 IoU: 100 detect: All_TN
# Number: 509 IoU: 100 detect: All_TN
# Number: 510 IoU: 100 detect: All_TN
# Number: 511 IoU: 100 detect: All_TN
# Number: 512 IoU: 100 detect: All_TN
# Number: 513 IoU: 100 detect: All_TN
# Number: 514 IoU: 100 detect: All_TN
# Number: 515 IoU: 100 detect: All_TN
# Number: 516 IoU: 100 detect: All_TN
# Number: 517 IoU: 100 detect: All_TN
# Number: 518 IoU: 100 detect: All_TN
# Number: 519 IoU: 100 detect: All_TN
# Number: 520 IoU: 100 detect: All_TN
# Number: 521 IoU: 100 detect: All_TN
# Number: 522 IoU: 100 detect: All_TN
# Number: 523 IoU: 100 detect: All_TN
# Number: 524 IoU: 100 detect: All_TN
# Number: 525 IoU: 100 detect: All_TN
# Number: 526 IoU: 100 detect: All_TN
# Number: 527 IoU: 100 detect: All_TN
# Number: 528 IoU: 100 detect: All_TN
# Number: 529 IoU: 100 detect: All_TN
# Number: 530 IoU: 100 detect: All_TN
# Number: 531 IoU: 100 detect: All_TN
# Number: 532 IoU: 100 detect: All_TN
# Number: 533 IoU: 100 detect: All_TN
# Number: 534 IoU: 100 detect: All_TN
# Number: 535 IoU: 100 detect: All_TN
# Number: 536 IoU: 100 detect: All_TN
# Number: 537 IoU: 100 detect: All_TN
# Number: 538 IoU: 100 detect: All_TN
# Number: 539 IoU: 100 detect: All_TN
# Number: 540 IoU: 100 detect: All_TN
# Number: 541 IoU: 100 detect: All_TN
# Number: 542 IoU: 100 detect: All_TN
# Number: 543 IoU: 100 detect: All_TN
# Number: 544 IoU: 100 detect: All_TN
# Number: 545 IoU: 100 detect: All_TN
# Number: 546 IoU: 100 detect: All_TN
# Number: 547 IoU: 100 detect: All_TN
# Number: 548 IoU: 100 detect: All_TN
# Number: 549 IoU: 100 detect: All_TN
# Average IoU: 49.55930187297691

# %%
import pandas as pd
df = pd.DataFrame(result_iou)
df.columns = columns
df.index = index
df.to_csv("pspnet_result_per_image.csv")

# %%
result_index = ["avg_iou", "No_detect", "Mis_detect", "Recall", "Precision"]
avg_iou = (sum_iou/count)

recall = count / (count + count_no_detect)
precision = count / (count + count_mis_detect)
result = [avg_iou, count_no_detect, count_mis_detect, recall, precision]
df = pd.DataFrame(result)
df.index = result_index
df.to_csv("pspnet_result.csv")
